# %%
import yfinance as yf
import pandas as pd

# %%
india_indexes = ['NIFTY_IND_TOURISM.NS', '^NSEI', '^BSESN']
tickers = ['VXUS']

data = yf.download(india_indexes + tickers, period='1d', group_by='ticker')
data.head()
data_long = data.stack(level=0, future_stack=True)
data_long.head()
# long_data = pd.melt(data, id_vars=['Date'], var_name='Ticker', value_name='Close')
# long_data.head()
# Out:
# [*********************100%***********************]  4 of 4 completed
# Price                                    Open          High           Low  \
# Date       Ticker
# 2026-05-05 ^NSEI                          NaN           NaN           NaN
#            ^BSESN                         NaN           NaN           NaN
#            NIFTY_IND_TOURISM.NS           NaN           NaN           NaN
#            VXUS                     83.120003     83.550003     82.900002
# 2026-05-06 ^NSEI                 24171.000000  24356.500000  23997.900391
#
# Price                                   Close     Volume
# Date       Ticker
# 2026-05-05 ^NSEI                          NaN        NaN
#            ^BSESN                         NaN        NaN
#            NIFTY_IND_TOURISM.NS           NaN        NaN
#            VXUS                     83.410004  4965800.0
# 2026-05-06 ^NSEI                 24330.949219        0.0
